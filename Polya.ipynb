# %%
import numpy as np
import matplotlib.pyplot as plt
import random

M = 1000 # simulations
N = 2000 # trials

A = np.zeros((M,N+1)) # matrix (simulations x trials)


for i in range(M): # for every simulation
    g=1
    r=1
    
    A[i,0]=g # initial column value of the matrix 
    
    
    for n in range (1,N+1): # trials
        
        prob_green = g/(r+g)
        
        if random.random()<prob_green: 
            g+=1
        else:
            r+=1
        
        A[i,n]=g
        
n = N
X_n = A[:,n]/(n+2) # vector of the proportions of green balls at the end of the trials for every simulation

plt.figure(figsize=(8, 5))
plt.hist(Xn, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black', label='Simulated Proportions')
plt.title(f'Distribution of X_{n} for {M} Simulations of {N} Trials')
plt.xlabel('Proportion of Green Balls')
plt.ylabel('Density')

# Plot the theoretical uniform distribution for comparison
x = np.linspace(0, 1, 100)
plt.plot(x, [1]*len(x), 'r--', label='Uniform[0,1] Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
